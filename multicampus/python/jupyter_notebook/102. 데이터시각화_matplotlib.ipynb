# %%
import matplotlib.pyplot as plt

# %%
plt.plot([10,20,30,40])
plt.show() # 원래는 show() 까지 해야한다.

# %%
plt.plot([10,20,30,40],[15,74,25,65])
plt.title("multi_king!")
plt.show()

# %%
plt.title("multi_king!")
plt.plot([10,20,30,40],[15,74,25,65], label = 'aaa')
plt.plot([10,20,30,40],[10,20,30,40], label = 'bbb')
plt.legend()
plt.show()

# %%
plt.title("multi_king!")
plt.plot([10,20,30,40],[15,74,25,65], color='green', label = 'aaa')
plt.plot([10,20,30,40],[10,20,30,40], color='black', label = 'bbb')
plt.legend()
plt.show()

# %%
plt.title("marker")
plt.plot([10,20,30,40],[15,74,25,65], 'r.', label = 'circle')
plt.plot([10,20,30,40],[10,20,30,40], 'b^', label = 'trianle_up')
plt.legend()
plt.show()

# %% [markdown]
# ### 데이터 읽어 최고 기온 데이터 출력하기

# %%
import csv
f = open('C:/Users/rkdtk/TIL/multicampus/python/jupyter_notebook/data/seoul_book.csv')
data = csv.reader(f)
next(data)
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']

# %%
for row in data:
    print(row[-1])
# Out:
# 20.7
# 22
# 21.3
# 22
# 25.4
# 21.3
# 16.1
# 14.9
# 21.1
# 24.1
# 20.4
# 17.4
# 21.3
# 20.6
# 20.9
# 20.2
# 21.6
# 20.9
# 21.3
# 22.7
# 19.9
# 19.6
# 16.3
# 17.1
# 18.7
# 18.2
# 20.7
# 19.6
# 20
# 20.1
# 20.3
# 21.3
# 21.1
# 11.1
# 13.6
# 17
# 18.1
# 12.4
# 9.4
# 11.9
# 13.2
# 13.4
# 14.9
# 16.4
# 15.2
# 17.6
# 12.6
# 11.7
# 6.7
# 4.3
# 7.1
# 6.2
# 11.2
# 9.9
# 5.9
# -0.7
# 1.5
# 1.9
# 2
# 2.9
# -2.4
# 1.4
# 3.4
# 6.1
# 1.3
# 2.6
# 5.8
# 1.9
# 6.6
# 8.1
# 4.3
# 0.6
# 3.8
# 9
# 6.4
# -5.1
# -2.4
# -2.1
# -0.4
# -0.2
# 1.9
# -8.1
# -10.2
# -9.4
# 0.9
# 6.8
# 6.4
# -0.7
# -1.9
# -4.4
# -6.1
# -2.1
# -1.3
# -3
# -2.9
# -1.7
# -0.1
# 2.9
# -1.2
# -0.9
# 2
# 3.3
# 4.8
# 4.5
# 4.7
# 0.1
# 0.9
# -4.5
# -3.6
# 2.8
# 2.8
# 2.3
# -6.1
# -5.1
# -2.7
# 0.1
# 0.3
# -0.6
# 0
# -1.3
# 0.8
# 0.8
# 6.2
# 1.6
# -0.2
# -5.4
# -4.1
# -5.5
# -5.7
# -3.7
# 1.3
# -4.1
# -2.5
# -2.8
# -1.2
# 1.3
# 2.3
# 2
# -1.4
# -1.6
# 0.3
# 5.5
# 7.3
# 5.1
# 5.4
# 2.7
# 1.7
# 0.8
# 4.1
# 8.4
# 6.3
# 5.6
# 4
# 0.1
# 4.9
# ...

# %%
import csv
import matplotlib.pyplot as plt

f = open('C:/Users/rkdtk/TIL/multicampus/python/jupyter_notebook/data/seoul_book.csv')
data = csv.reader(f)
next(data)
result = []

for row in data:
    if row[-1] != '':
        result.append(float(row[-1]))
print("result",result)
# Out:
# result [20.7, 22.0, 21.3, 22.0, 25.4, 21.3, 16.1, 14.9, 21.1, 24.1, 20.4, 17.4, 21.3, 20.6, 20.9, 20.2, 21.6, 20.9, 21.3, 22.7, 19.9, 19.6, 16.3, 17.1, 18.7, 18.2, 20.7, 19.6, 20.0, 20.1, 20.3, 21.3, 21.1, 11.1, 13.6, 17.0, 18.1, 12.4, 9.4, 11.9, 13.2, 13.4, 14.9, 16.4, 15.2, 17.6, 12.6, 11.7, 6.7, 4.3, 7.1, 6.2, 11.2, 9.9, 5.9, -0.7, 1.5, 1.9, 2.0, 2.9, -2.4, 1.4, 3.4, 6.1, 1.3, 2.6, 5.8, 1.9, 6.6, 8.1, 4.3, 0.6, 3.8, 9.0, 6.4, -5.1, -2.4, -2.1, -0.4, -0.2, 1.9, -8.1, -10.2, -9.4, 0.9, 6.8, 6.4, -0.7, -1.9, -4.4, -6.1, -2.1, -1.3, -3.0, -2.9, -1.7, -0.1, 2.9, -1.2, -0.9, 2.0, 3.3, 4.8, 4.5, 4.7, 0.1, 0.9, -4.5, -3.6, 2.8, 2.8, 2.3, -6.1, -5.1, -2.7, 0.1, 0.3, -0.6, 0.0, -1.3, 0.8, 0.8, 6.2, 1.6, -0.2, -5.4, -4.1, -5.5, -5.7, -3.7, 1.3, -4.1, -2.5, -2.8, -1.2, 1.3, 2.3, 2.0, -1.4, -1.6, 0.3, 5.5, 7.3, 5.1, 5.4, 2.7, 1.7, 0.8, 4.1, 8.4, 6.3, 5.6, 4.0, 0.1, 4.9, 4.0, 7.9, 7.9, 2.2, 1.9, 1.5, 1.5, 1.8, 2.6, 3.8, 6.7, 11.8, 13.5, 15.7, 10.7, 7.9, 4.3, 6.0, 12.5, 17.0, 14.7, 11.4, 7.4, 8.
# ...

# %%
plt.plot(result,'r')
plt.show()

# %% [markdown]
# ### [참고]

# %%
s = "hello python"
print(s.split()) # 공백기준을 나눠줘
# Out:
# ['hello', 'python']

# %%
date = "2021-12-28"
print(date.split('-'))
date = date.split('-')
# Out:
# ['2021', '12', '28']

# %%
print(date[0])
print(date[1])
print(date[2])
# Out:
# 2021
# 12
# 28

# %% [markdown]
# #### 주어진 데이터에서 8월의 최고 기온 데이터 시각화 하기

# %%
import csv
import matplotlib.pyplot as plt

f = open('./data/seoul_book.csv')
data = csv.reader(f)
next(data)
high = []
low = []

for row in data:
    if row[-1] != '' and row[-2] != '':
        if row[0].split('-')[1] == '01' and row[0].split('-')[2] == '21':
            high.append(float(row[-1]))
            low.append(float(row[-2]))

plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False # 한글폰트 사용시 에러 해결
plt.title("내 생일 기온 변화 그래프 (1/21)")
plt.plot(high, 'red', label='high')
plt.plot(low, 'blue', label ='low')
plt.legend()
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('./seoul.csv', encoding = "utf-8")
data = csv.reader(f)
next(data)
# Out:
# ['\t\t지점번호',
#  '지점명',
#  '일시',
#  '평균기온(℃)',
#  '평균최고기온(℃)',
#  '최고기온(℃)',
#  '\t최고기온일자',
#  '평균최저기온(℃)',
#  '최저기온(℃)',
#  '최저기온일자']

# %%
for row in data:
    print(row)
# Out:
# ['\t\t108', '서울', '2008-01', '-1.7', '1.9', '7.3', '2008-01-06', '-5.0', '-11.1', '2008-01-17']
# ['\t\t108', '서울', '2008-02', '-1.2', '3.2', '10.5', '2008-02-22', '-4.9', '-10.1', '2008-02-13']
# ['\t\t108', '서울', '2008-03', '7.3', '11.9', '19.8', '2008-03-21', '3.7', '-1.7', '2008-03-05']
# ['\t\t108', '서울', '2008-04', '14.1', '19.5', '28.0', '2008-04-19', '9.3', '3.8', '2008-04-04']
# ['\t\t108', '서울', '2008-05', '17.7', '22.7', '28.5', '2008-05-29', '13.1', '8.1', '2008-05-14']
# ['\t\t108', '서울', '2008-06', '21.5', '26.1', '29.6', '2008-06-20', '17.6', '13.7', '2008-06-05']
# ['\t\t108', '서울', '2008-07', '25.1', '28.4', '32.9', '2008-07-09', '22.6', '20.2', '2008-07-01']
# ['\t\t108', '서울', '2008-08', '25.3', '29.5', '35.4', '2008-08-08', '21.8', '16.3', '2008-08-22']
# ['\t\t108', '서울', '2008-09', '22.0', '26.9', '32.0', '2008-09-17', '18.0', '10.3', '2008-09-27']
# ['\t\t108', '서울', '2008-10', '16.1', '21.0', '28.3', '2008-10-18', '12.1', '5.6', '2008-10-28']
# ...

# %%
import csv
import matplotlib.pyplot as plt

f = open('./seoul_new.csv')
data = csv.reader(f)
header = next(data)
print(header)
high = []
low = []

for row in data:
    if row[-1] != '' and row[-2] != '':
        if row[0].split('-')[1] == '01' and row[0].split('-')[2] == '21':
            high.append(float(row[-1]))
            low.append(float(row[-2]))

plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False # 한글폰트 사용시 에러 해결
plt.title("내 생일 기온 변화 그래프 (1/21)")
plt.plot(high, 'red', label='high')
plt.plot(low, 'blue', label ='low')
plt.legend()
plt.show()
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']

# %%
# Out:
# ['1907-10-01', '108', '13.5', '7.9', '20.7']
