# %%
import csv
import matplotlib.pyplot as plt

f = open('./data/seoul_book.csv')
data = csv.reader(f)
next(data)
high = []
low = []

for row in data:
    if row[-1] != '' and row[-2] != '':
        if row[0].split('-')[1] == '01' and row[0].split('-')[2] == '21':
            high.append(float(row[-1]))
            low.append(float(row[-2]))

plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False # 한글폰트 사용시 에러 해결
plt.title("내 생일 기온 변화 그래프 (1/21)")
plt.plot(high, 'red', label='high')
plt.plot(low, 'blue', label ='low')
plt.legend()
plt.show()
