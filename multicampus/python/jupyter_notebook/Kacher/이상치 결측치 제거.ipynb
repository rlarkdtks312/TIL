# %%
import pandas as pd
import numpy as np

# %%
shops=pd.read_csv("./shops.csv")
shops
# Out:
#                                           shop_name  shop_id
# 0                     !Якутск Орджоникидзе, 56 фран        0
# 1                     !Якутск ТЦ "Центральный" фран        1
# 2                                  Адыгея ТЦ "Мега"        2
# 3                    Балашиха ТРК "Октябрь-Киномир"        3
# 4                          Волжский ТЦ "Волга Молл"        4
# 5                            Вологда ТРЦ "Мармелад"        5
# 6                        Воронеж (Плехановская, 13)        6
# 7                            Воронеж ТРЦ "Максимир"        7
# 8                      Воронеж ТРЦ Сити-Парк "Град"        8
# 9                                 Выездная Торговля        9
# 10                       Жуковский ул. Чкалова 39м?       10
# 11                       Жуковский ул. Чкалова 39м²       11
# 12                              Интернет-магазин ЧС       12
# 13                              Казань ТЦ "Бехетле"       13
# ...

# %%
# 0 list = [[62.02522883338076, 129.72024199904732],
# 1        [62.037301616892094, 129.71780739602482],
# 2       [45.01296654205926, 38.930381394697974],
# 3        [55.79662072030961, 37.926708269234666],
# 4        [48.77213659373243, 44.79983092746513],
# 5        [59.19933176339063, 39.85963296975052],
# 6        [51.6637860957119, 39.19722065453178],
# 7        [51.69703307855997, 39.273326600570286],
# 8        [51.78903488096228, 39.205010727554324],
# 9        [51.6723172161094, 39.16413488151351],
# 10       [55.59725083672762, 38.123644998835836],
# 11        [55.59962715658703, 38.12065574116319],
# 12        [55.74425126787867, 37.85613088382025],
# 13        [55.86102167353668, 48.90016731558103],
# 14        [55.83006084581892, 49.118158070006814],
# 15        [54.51627336977013, 36.24648783160098],
# 16        [55.084435206187386, 38.80062722765616],
            [56.034563392471625, 92.90775169884985],
            [56.037444791193835, 92.93459674303213],
            []] 
22
# Out:
# (45.01296654205926, 38.930381394697974)

# %%
shops['shop_name'].shape
# Out:
# (60,)

# %%
shops['shop_name'].value_counts().sum()
# Out:
# 60

# %%
# 가치가 없음
shops.describe()
# Out:
#          shop_id
# count  60.000000
# mean   29.500000
# std    17.464249
# min     0.000000
# 25%    14.750000
# 50%    29.500000
# 75%    44.250000
# max    59.000000

# %%
# !pip install -U googlemaps
# Out:
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.6.0-py3-none-any.whl size=38552 sha256=0421606af071939b81dea8c69e69dc003a5263157697f72e3041ded94081fdb7
#   Stored in directory: c:\users\rkdtk\appdata\local\pip\cache\wheels\2d\e9\ee\336c1792ed04efbf4fe9c89662d701f5c1f1fdddf8782951d3
# Successfully built googlemaps
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\rkdtk\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import requests
import privacy as pr

API = pr.K_API

searching = '!Якутск Орджоникидзе, 56 фран'
url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)
headers = {
    "Authorization": "KakaoAK {}".format(API)
}
places = requests.get(url, headers = headers).json()['documents']
places
# Out:
# []
