# %%
import pandas as pd

# %%
df = pd.read_excel('../data/samsung_smartphone.csv.xlsx')
df
# Out:
# C:\Users\rkdtk\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#             뉴스 식별자        일자     언론사             기고자  \
# 0     1.100201e+06  20220307    국민일보             양한주
# 1     2.100701e+06  20220307   헤럴드경제          박혜림 기자
# 2     2.100311e+06  20220307    서울경제          윤민혁 기자
# 3     1.100611e+06  20220307    서울신문             나상현
# 4     7.100501e+06  20220307    전자신문  전자신문인터넷 양민하 기자
# ...            ...       ...     ...             ...
# 1275  1.100401e+06  20211207    동아일보             서형석
# 1276  2.100101e+06  20211207    매일경제     이승훈,오찬종,박재영
# 1277  1.500051e+06  20211207    경남신문            연합뉴스
# 1278  2.100501e+06  20211207  파이낸셜뉴스             이보미
# 1279  2.100501e+06  20211207  파이낸셜뉴스             김준혁
#
#                                           제목     통합 분류1      통합 분류2  \
# ...

# %%
df.head()
# Out:
#          뉴스 식별자        일자    언론사             기고자  \
# 0  1.100201e+06  20220307   국민일보             양한주
# 1  2.100701e+06  20220307  헤럴드경제          박혜림 기자
# 2  2.100311e+06  20220307   서울경제          윤민혁 기자
# 3  1.100611e+06  20220307   서울신문             나상현
# 4  7.100501e+06  20220307   전자신문  전자신문인터넷 양민하 기자
#
#                                      제목     통합 분류1      통합 분류2 통합 분류3  \
# 0  삼성, 중저가 시장서 명예회복 노린다 A시리즈로 아이폰SE와 격돌  IT_과학>모바일   IT_과학>콘텐츠    NaN
# 1        “삼성, 정말 이래도 돼?” 싸다고 ‘이것’까지 없앤다  IT_과학>모바일   IT_과학>콘텐츠    NaN
# 2        삼성전자, '랩서스' 해킹 관해 "고객정보 유출 없어"   IT_과학>보안   IT_과학>모바일    NaN
# 3       삼성 “해킹 자료에 임직원 고객 개인 정보 포함 안됐다”   IT_과학>보안   IT_과학>모바일    NaN
# 4    "갤럭시A 붙자"...공개 임박 애플 '아이폰SE3' 스펙은?  IT_과학>모바일         NaN    NaN
#
#   사건/사고 분류1 사건/사고 분류2  사건/사고 분류3   인물      위치  \
# 0       NaN       NaN        NaN  NaN      중국
# 1       NaN       NaN        NaN  NaN     NaN
# 2       NaN       NaN        NaN  NaN      미국
# 3       NaN       NaN        NaN  NaN  미국,토렌트
# ...

# %%
df.본문
# Out:
# 0       삼성전자가 이르면 이달 중 보급형 스마트폰인 갤럭시 A 시리즈를 선보인다. 2년 만...
# 1       [헤럴드경제=박혜림 기자] “싸다고 충전기까지 뺀다?” \n \n 삼성전자가 중저가...
# 2       삼성전자(005930)가 외국 해커 그룹 ‘랩서스(LAPSUS＄)’로부터 해킹 당했...
# 3       삼성전자가 최근 외국 해커그룹 랩서스(LAPSUS$)로부터 해킹 공격을 받은 것과 ...
# 4       애플이 오는 9일 스페셜 이벤트를 통해 '아이폰SE' 신제품을 선보일 전망이다. 홈...
#                               ...
# 1275    반도체를 비롯한 스마트폰 부품 값 상승 여파로 삼성전자가 차기 전략 스마트폰 가격을...
# 1276    삼성전자가 대표이사 3명을 전면 교체하는 인사를 단행한다. 업계에 따르면 삼성전자는...
# 1277    전 세계적인 반도체 대란이 장기화하면서 스마트폰 가격 인상이 현실화하고 있다. \n...
# 1278    아이폰13 출시된 10월에만 \n이통3사 순증 가입 97만명 \n삼성 폴더블폰 Z시...
# 1279    애플은 전분기보다 5%P 감소 \n\n \n\n \n삼성전자가 올 3 4분기 갤럭시...
# Name: 본문, Length: 1280, dtype: object

# %%
# !pip install eunjeon
# Out:
# ...
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\rkdtk\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\rkdtk\\AppData\\Local\\Temp\\pip-install-10xuazzt\\eunjeon_b40661ff0df64aa4b040e5644c1338ef\\setup.py'"'"'; __file__='"'"'C:\\Users\\rkdtk\\AppData\\Local\\Temp\\pip-install-10xuazzt\\eunjeon_b40661ff0df64aa4b040e5644c1338ef\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\rkdtk\AppData\Local\Temp\pip-wheel-8vhrfg01'
#        cwd: C:\Users\rkdtk\AppData\Local\Temp\pip-install-10xuazzt\eunjeon_b40661ff0df64aa4b040e5644c1338ef\
#   Complete output (44 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
# ...

# %%
# !pip install eunjeon
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [44 lines of output]
#   running bdist_wheel
#   running build
#   Using cached eunjeon-0.4.0.tar.gz (34.7 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py clean for eunjeon
# Failed to build eunjeon
# ...
#   Running setup.py install for eunjeon: started
#   Running setup.py install for eunjeon: finished with status 'error'
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.8
#   creating build\lib.win-amd64-3.8\eunjeon
#   copying eunjeon\constants.py -> build\lib.win-amd64-3.8\eunjeon
#   copying eunjeon\mecab.py -> build\lib.win-amd64-3.8\eunjeon
#   copying eunjeon\_mecab.py -> build\lib.win-amd64-3.8\eunjeon
#   copying eunjeon\__init__.py -> build\lib.win-amd64-3.8\eunjeon
#   creating build\lib.win-amd64-3.8\eunjeon\data
# ...
