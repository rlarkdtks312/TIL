# %%
import pandas as pd
import numpy as np

# %%
location_counts_df = pd.read_excel('./5_Jeju_Hotplace/files/1_crawling_raw.xlsx')
location_counts_df['place'].value_counts()
# Out:
# Jeju                    271
# Jeju-do                 179
# Jungle Book by Alice    108
# Seogwipo                 66
# 제주도 크리스마스 박물관            59
#                        ...
# 제주마당                      1
# 형제섬                       1
# 동복해녀식당                    1
# 종로 광장시장                   1
# 디스이즈핫                     1
# Name: place, Length: 1028, dtype: int64

# %%
import requests
import privacy as pr

searching = '제주공항'
url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)

headers = {
    "Authorization": 'KakaoAK {}'.format(pr.K_API) 
}

places = requests.get(url, headers = headers).json()['documents']
places
# Out:
# [{'address_name': '제주특별자치도 제주시 용담2동 2002',
#   'category_group_code': '',
#   'category_group_name': '',
#   'category_name': '교통,수송 > 교통시설 > 공항',
#   'distance': '',
#   'id': '10808261',
#   'phone': '1661-2626',
#   'place_name': '제주국제공항',
#   'place_url': 'http://place.map.kakao.com/10808261',
#   'road_address_name': '제주특별자치도 제주시 공항로 2',
#   'x': '126.492769004244',
#   'y': '33.5070789578184'},
#  {'address_name': '제주특별자치도 제주시 용담2동 2002',
#   'category_group_code': '',
#   'category_group_name': '',
#   'category_name': '교통,수송 > 입출구',
#   'distance': '',
#   'id': '1066115422',
#   'phone': '',
#   'place_name': '제주국제공항 국내선출발 3번게이트',
#   'place_url': 'http://place.map.kakao.com/1066115422',
#   'road_address_name': '제주특별자치도 제주시 공항로 2',
#   'x': '126.492948320949',
#   'y': '33.506596439862'},
#  {'address_name': '제주특별자치도 제주시 용담2동 1984-8',
#   'category_group_code': '',
#   'category_group_name': '',
#   'category_name': '서비스,산업 > 전문대행 > 렌터카',
#   'distance': '',
# ...

# %%
def find_places(searching):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)
    
    headers = {
    "Authorization": 'KakaoAK {}'.format(pr.K_API) 
    }
    
    places = requests.get(url, headers = headers).json()['documents']
    
    place = places[0]
    
    name = place['place_name']
    x = place['x']
    y = place['y']
    
    data = [name, x, y, searching]
    
    return data

# %%
data = find_places('제주공항')
data
# Out:
# ['제주국제공항', '126.492769004244', '33.5070789578184', '제주공항']

# %%
from tqdm.notebook import tqdm

# %%
df1 = pd.DataFrame(['a','b','c','e'], columns=['name'])
df1
# Out:
#   name
# 0    a
# 1    b
# 2    c
# 3    e

# %%
df2 = pd.DataFrame([100, 200, 140, 160], index=['a','b','c','d'], columns=['price'])
df2
# Out:
#    price
# a    100
# b    200
# c    140
# d    160

# %%
pd.merge(df1,df2, how = 'inner', left_on = 'name', right_index=True)
# Out:
#   name  price
# 0    a    100
# 1    b    200
# 2    c    140
